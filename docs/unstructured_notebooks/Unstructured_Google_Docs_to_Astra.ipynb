# %% [markdown]
# ## Embed your Google Drive Docs in a DataStax Astra Vector Database with Unstructured!

# %% [markdown]
# Author: Nina Lopatina from Unstructured
#
# Nina's X handle: [@NinaLopatina](https://x.com/ninalopatina)
#
# Nina's LinkedIn: https://www.linkedin.com/in/ninalopatina
#
# Last updated: 09.05.24

# %% [markdown]
# Do you have some files in Google Docs that you want to parse, embed, and import to your Astra DataBase for RAG? If so, this notebook will guide you through all the steps to do so!
#
# Here are the initial non-code steps:
#
# A. Sign up for your [Unstructured API key](https://app.unstructured.io/) with a 2 week free trial for up to 1000 documents. You can find your API credentials in your dashboard.
#
# B. Create a [Google Drive service acount](https://support.google.com/a/answer/7378726?hl=en) or find your json with your login info. Make sure you share the google drive directory your data is stored in with the service account email address.
#
# C. Sign up to get your [AstraDB](https://www.google.com/url?q=https%3A%2F%2Fwww.datastax.com%2Flp%2Fastra-registration) DB endpoint and token
#
# D. Decide on which embeddings to use, and obtain the appropriate API Token as needed (in this notebook we are using OpenAI for embedding generation).
#
# Set up the any private API keys in a .env file in your Google Drive
# _______________
#
#
#
#
# 1. Now starting with the code below, we will install all the necessary libraries

# %%
# !pip install -q -U "unstructured-ingest[google-drive, astradb, embed-huggingface]" langchain-community httpx python-dotenv
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 1.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 6.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 31.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 42.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 396.4/396.4 kB 20.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.2/290.2 kB 19.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.6/156.6 kB 11.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 8.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.0/64.0 kB 4.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.7/149.7 kB 12.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 67.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 395.9/395.9 kB 23.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.1/45.1 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 3.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 9.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 49.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 12.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 431.4/431.4 kB 24.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 274.7/274.7 kB 17.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 77.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.9/18.9 MB 58.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.7/82.7 kB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 16.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.8/295.8 kB 17.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 3.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.6/114.6 kB 8.3 MB/s eta 0:00:00
#   Building wheel for langdetect (setup.py) ... done

# %% [markdown]
# 2. [Mount your Google drive locally](https://colab.research.google.com/notebooks/io.ipynb) -- there will be a pop up asking you to connect to your google drive -- to load your dotenv file, and to store your .json locally in case you want to reference them later.
#
#   The files themselves will be pulled via a connector to a service account, which allows for processing of google doc files in addition to standard file formats that can be saved in your Drive.
#
#   The secret parameters to set in your .env file are:
#
#   UNSTRUCTURED_API_KEY
#
#   UNSTRUCTURED_PARTITION_ENDPOINT
#
#   ASTRA_DB_TOKEN
#
#   ASTRA_DB_ENDPOINT

# %% [markdown]
# ### Note that in this notebook, you are sharing your Google Drive with the colab notebook itself, not with Unstructured or DataStax.
#   If you prefer not to share your notebook, you can access your .env and Drive .json files in another fashion, e.g. by downloading this notebook as a .ipynb and running it locally with local directory access.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import dotenv

dotenv.load_dotenv('/content/drive/MyDrive/.env')
# Out:
# True

# %% [markdown]
# 3. We will set additional parameters here, that are not secret, that we can modify more easily in a notebook

# %%
from google.colab import userdata

os.environ['GCP_SERVICE_ACCOUNT_KEY'] = '/content/drive/MyDrive/secret/unstructured-podcast-efb838617cbd.json'  # The json you downloaded for your account key # #json path # userdata.get('Google-json-output')
os.environ['GOOGLE_DRIVE_FOLDER_ID'] = '1cF_wp5Mkuiyvrcee0KKBWWmLcyPj8BiP' # The folder where your unstructured data is contained #full '1lBSoQJAg1Tbaer5Z99XI8P4-F16BSWTM' #  #test # '1cF_wp5Mkuiyvrcee0KKBWWmLcyPj8BiP'
os.environ['LOCAL_FILE_DOWNLOAD_DIR'] = '/content/drive/MyDrive/output78/'
os.environ['ASTRA_DB_COLLECTION'] = 'ninatest'
os.environ['ASTRA_DB_EMBEDDING_DIMENSIONS'] = '384' #This value depends on the embedding model you choose. For our current default model per provider, the current values are 384 for HF and 1536 for OpenAI
os.environ["ASTRA_DB_NAMESPACE"] = 'nina_namespace'

# %% [markdown]
# #### Note that we temporarily have a bug in processing Docs, Sheets, and Slides in Google Docs (.doc, .xlsx, .ppt, etc., would work fine) -- as a temporary workaround, you can use the V1 SDK code, or download and upload your files)

# %% [markdown]
# 4. Set up Unstructured API access and process the documents as per our [Google Drive source connector](https://docs.unstructured.io/open-source/ingest/source-connectors/google-drive) documentation and set up the [Astra destination connector](https://docs.unstructured.io/open-source/ingest/destination-connectors/astra). Note that these will shortly be updated to for our new Serverless API.
#
#   At the end of this workflow, your unstructured documents have been extracted, chunked, summarized, embedded, and loaded in your Astra DB!

# %%
#All of the imports
from unstructured_ingest.v2.pipeline.pipeline import Pipeline
from unstructured_ingest.v2.interfaces import ProcessorConfig
from unstructured_ingest.v2.processes.partitioner import PartitionerConfig
from unstructured_ingest.v2.processes.chunker import ChunkerConfig
from unstructured_ingest.v2.processes.embedder import EmbedderConfig


from unstructured_ingest.v2.processes.connectors.google_drive import (
    GoogleDriveConnectionConfig,
    GoogleDriveAccessConfig,
    GoogleDriveIndexerConfig,
    GoogleDriveDownloaderConfig
)
from unstructured_ingest.v2.processes.connectors.astradb import (
    AstraDBConnectionConfig,
    AstraDBAccessConfig,
    AstraDBUploadStagerConfig,
    AstraDBUploaderConfig
)
import os

# %%
Pipeline.from_configs(
    context=ProcessorConfig(),
    indexer_config=GoogleDriveIndexerConfig(),
    downloader_config=GoogleDriveDownloaderConfig(download_dir=os.getenv("LOCAL_FILE_DOWNLOAD_DIR")),
    source_connection_config=GoogleDriveConnectionConfig(
                access_config=GoogleDriveAccessConfig(
                    service_account_key_path=os.getenv("GCP_SERVICE_ACCOUNT_KEY")
                ),
                drive_id=os.getenv("GOOGLE_DRIVE_FOLDER_ID"),
            ),
    partitioner_config=PartitionerConfig(
            partition_by_api=True,
            api_key=os.getenv("UNSTRUCTURED_API_KEY"),
            partition_endpoint=os.getenv("UNSTRUCTURED_API_URL"),
            strategy="hi_res",
            additional_partition_args={
                "split_pdf_page": True,
                "split_pdf_allow_failed": True,
                "split_pdf_concurrency_level": 15
            }
        ),
    chunker_config=ChunkerConfig(chunking_strategy="by_title"),
    embedder_config=EmbedderConfig(embedding_provider="langchain-huggingface"),
    destination_connection_config=AstraDBConnectionConfig(
            access_config=AstraDBAccessConfig(
                api_endpoint=os.getenv("ASTRA_DB_API_ENDPOINT"),
                token=os.getenv("ASTRA_DB_APPLICATION_TOKEN")
            )
        ),
    stager_config=AstraDBUploadStagerConfig(),
    uploader_config=AstraDBUploaderConfig(
        namespace=os.getenv("ASTRA_DB_NAMESPACE"),
        collection_name=os.getenv("ASTRA_DB_COLLECTION"),
        embedding_dimension=os.getenv("ASTRA_DB_EMBEDDING_DIMENSIONS")
    )
).run()
# Out:
# 2024-09-06 00:09:28,254 MainProcess INFO     Created index with configs: {"extensions": null, "recursive": false}, connection configs: {"access_config": "**********", "drive_id": "1cF_wp5Mkuiyvrcee0KKBWWmLcyPj8BiP"}
# 2024-09-06 00:09:28,260 MainProcess INFO     Created download with configs: {"download_dir": "/content/drive/MyDrive/output78"}, connection configs: {"access_config": "**********", "drive_id": "1cF_wp5Mkuiyvrcee0KKBWWmLcyPj8BiP"}
# 2024-09-06 00:09:28,265 MainProcess INFO     Created partition with configs: {"strategy": "hi_res", "ocr_languages": null, "encoding": null, "additional_partition_args": {"split_pdf_page": true, "split_pdf_allow_failed": true, "split_pdf_concurrency_level": 15}, "skip_infer_table_types": null, "fields_include": ["element_id", "text", "type", "metadata", "embeddings"], "flatten_metadata": false, "metadata_exclude": [], "metadata_include": [], "partition_endpoint": null, "partition_by_api": true, "api_key": "*******", "hi_res_model_name": null}
# 2024-09-06 00:09:28,271 MainProcess INFO     Created chunk with configs: {"chunking_strategy": "by_title", "chunking_endpoint": "https://api.unstructured.io/general/v0/general", "chunk_by_api": false, "chunk_api_key": null, "chunk_combine_text_under_n_chars": null, "chunk_include_orig_elements": null, "chunk_max_characters": 500, "chunk_multipage_sections": true, "chunk_new_after_n_chars": null, "chunk_overlap": null, "chunk_overlap_all": null}
# 2024-09-06 00:09:28,274 MainProcess INFO     Created embed with configs: {"embedding_provider": "langchain-huggingface", "embedding_api_key": null, "embedding_model_name": null, "embedding_aws_access_key_id": null, "embedding_aws_secret_access_key": null, "embedding_aws_region": "us-west-2"}
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/cross_encoder/CrossEncoder.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# 2024-09-06 00:09:53,739 MainProcess INFO     Created upload_stage with configs: {}
# 2024-09-06 00:09:53,740 MainProcess INFO     Created upload with configs: {"collection_name": "ninatest", "embedding_dimension": 384, "namespace": "nina_namespace", "requested_indexing_policy": null, "batch_size": 20}, connection configs: {"access_config": "**********", "connection_type": "astradb"}
# 2024-09-06 00:09:56,836 MainProcess INFO     Running local pipline: index (GoogleDriveIndexer) -> download (GoogleDriveDownloader) -> partition (hi_res) -> chunk (by_title) -> embed (langchain-huggingface) -> upload_stage (AstraDBUploadStager) -> upload (AstraDBUploader) with configs: {"reprocess": false, "verbose": false, "tqdm": false, "work_dir": "/root/.cache/unstructured/ingest/pipeline", "num_processes": 2, "max_connections": null, "raise_on_error": false, "disable_parallelism": false, "preserve_downloads": false, "download_only": false, "max_docs": null, "re_download": false, "uncompress": false, "otel_endpoint": null, "status": {}}
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# 2024-09-06 00:09:56,881 MainProcess INFO     index finished in 0.00014422s
# 2024-09-06 00:09:58,115 MainProcess INFO     Calling DownloadStep with 45 docs
# 2024-09-06 00:09:58,116 MainProcess INFO     processing content async
# 2024-09-06 00:09:58,120 MainProcess WARNING  async code being run in dedicated thread pool to not conflict with existing event loop: <_UnixSelectorEventLoop running=True closed=False debug=False>
# 2024-09-06 00:09:58,139 MainProcess INFO     download finished in 0.012977946s, attributes: file_id=e994c7cc1bc7
# 2024-09-06 00:09:58,152 MainProcess INFO     download finished in 0.009853994s, attributes: file_id=7b745a57b69d
# 2024-09-06 00:09:58,164 MainProcess INFO     download finished in 0.010461707s, attributes: file_id=e9ed27e3b8d8
# 2024-09-06 00:09:58,175 MainProcess INFO     download finished in 0.008777659s, attributes: file_id=abd3283f76d1
# 2024-09-06 00:09:58,187 MainProcess INFO     download finished in 0.008559268s, attributes: file_id=d3f25cd30105
# 2024-09-06 00:09:58,198 MainProcess INFO     download finished in 0.009947227s, attributes: file_id=c398325dcf56
# 2024-09-06 00:09:58,209 MainProcess INFO     download finished in 0.009782913s, attributes: file_id=f7b34d86c902
# 2024-09-06 00:09:58,220 MainProcess INFO     download finished in 0.009233996s, attributes: file_id=70728684bd95
# 2024-09-06 00:09:58,232 MainProcess INFO     download finished in 0.00934495s, attributes: file_id=2b66aba8df56
# 2024-09-06 00:09:58,244 MainProcess INFO     download finished in 0.009437511s, attributes: file_id=9a39d2e29dcc
# 2024-09-06 00:09:58,256 MainProcess INFO     download finished in 0.009390009s, attributes: file_id=4e1ff8c3cfa6
# 2024-09-06 00:09:58,267 MainProcess INFO     download finished in 0.009544405s, attributes: file_id=caea060664cc
# 2024-09-06 00:09:58,278 MainProcess INFO     download finished in 0.009282432s, attributes: file_id=ff5318340c6e
# 2024-09-06 00:09:58,291 MainProcess INFO     download finished in 0.010317609s, attributes: file_id=c8861f9318ac
# 2024-09-06 00:09:58,303 MainProcess INFO     download finished in 0.010828546s, attributes: file_id=7ae5ed524fa3
# 2024-09-06 00:09:58,316 MainProcess INFO     download finished in 0.01028515s, attributes: file_id=a0fb12601f92
# 2024-09-06 00:09:58,328 MainProcess INFO     download finished in 0.009756166s, attributes: file_id=d4b5721fc6ac
# 2024-09-06 00:09:58,340 MainProcess INFO     download finished in 0.010227874s, attributes: file_id=d7d2922d94ba
# 2024-09-06 00:09:58,351 MainProcess INFO     download finished in 0.008709334s, attributes: file_id=c3a5f10725a8
# 2024-09-06 00:09:58,363 MainProcess INFO     download finished in 0.009980598s, attributes: file_id=d01d0022be96
# 2024-09-06 00:09:58,375 MainProcess INFO     download finished in 0.00983722s, attributes: file_id=672104dd6749
# 2024-09-06 00:09:58,387 MainProcess INFO     download finished in 0.010240544s, attributes: file_id=b3d89bdb67ff
# 2024-09-06 00:09:58,398 MainProcess INFO     download finished in 0.009317274s, attributes: file_id=498c50401742
# 2024-09-06 00:09:58,410 MainProcess INFO     download finished in 0.010043808s, attributes: file_id=f4ba9aae9cf9
# 2024-09-06 00:09:58,422 MainProcess INFO     download finished in 0.009472537s, attributes: file_id=db2f21630cfc
# 2024-09-06 00:09:58,433 MainProcess INFO     download finished in 0.009218632s, attributes: file_id=f719093841a5
# 2024-09-06 00:09:58,445 MainProcess INFO     download finished in 0.00939602s, attributes: file_id=6bddf10193f2
# 2024-09-06 00:09:58,456 MainProcess INFO     download finished in 0.008938775s, attributes: file_id=ac75a8c380fe
# 2024-09-06 00:09:58,467 MainProcess INFO     download finished in 0.008776121s, attributes: file_id=6f763f4cca09
# 2024-09-06 00:09:58,478 MainProcess INFO     download finished in 0.008893109s, attributes: file_id=f97a843986db
# 2024-09-06 00:09:58,491 MainProcess INFO     download finished in 0.011020223s, attributes: file_id=b62949260afa
# 2024-09-06 00:09:58,504 MainProcess INFO     download finished in 0.010102102s, attributes: file_id=d607933d117f
# 2024-09-06 00:09:58,515 MainProcess INFO     download finished in 0.008913449s, attributes: file_id=deb43f567179
# 2024-09-06 00:09:58,526 MainProcess INFO     download finished in 0.009396585s, attributes: file_id=7528aadeea11
# 2024-09-06 00:09:58,538 MainProcess INFO     download finished in 0.009298668s, attributes: file_id=bdba1adc010f
# 2024-09-06 00:09:58,550 MainProcess INFO     download finished in 0.009931814s, attributes: file_id=b38f5c0127d9
# 2024-09-06 00:09:58,618 MainProcess INFO     download finished in 0.065348106s, attributes: file_id=13765ca921e7
# 2024-09-06 00:09:58,634 MainProcess INFO     download finished in 0.013516251s, attributes: file_id=ed6e53262aa7
# 2024-09-06 00:09:58,656 MainProcess INFO     download finished in 0.01388255s, attributes: file_id=c61a1e69b092
# 2024-09-06 00:09:58,668 MainProcess INFO     download finished in 0.00956525s, attributes: file_id=0d0f018e3413
# 2024-09-06 00:09:58,681 MainProcess INFO     download finished in 0.011026392s, attributes: file_id=345d018cbbe5
# 2024-09-06 00:09:58,693 MainProcess INFO     download finished in 0.010827318s, attributes: file_id=c8772b42e222
# 2024-09-06 00:09:58,704 MainProcess INFO     download finished in 0.00854081s, attributes: file_id=cbf0e997e940
# 2024-09-06 00:09:58,718 MainProcess INFO     download finished in 0.010581213s, attributes: file_id=0049b10a4583
# 2024-09-06 00:09:58,730 MainProcess INFO     download finished in 0.010304878s, attributes: file_id=82b1d0b5fd74
# 2024-09-06 00:09:58,734 MainProcess INFO     download step finished in 0.619298564s
# 2024-09-06 00:09:58,736 MainProcess INFO     Calling PartitionStep with 45 docs
# 2024-09-06 00:09:58,737 MainProcess INFO     processing content async
# 2024-09-06 00:09:58,741 MainProcess WARNING  async code being run in dedicated thread pool to not conflict with existing event loop: <_UnixSelectorEventLoop running=True closed=False debug=False>
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# 2024-09-06 00:10:14,559 MainProcess INFO     partition finished in 15.393922956s, attributes: file_id=7b745a57b69d
# INFO: partition finished in 15.393922956s, attributes: file_id=7b745a57b69d
# 2024-09-06 00:10:14,883 MainProcess INFO     partition finished in 15.391465042s, attributes: file_id=e9ed27e3b8d8
# INFO: partition finished in 15.391465042s, attributes: file_id=e9ed27e3b8d8
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# 2024-09-06 00:10:15,864 MainProcess INFO     partition finished in 16.07456895s, attributes: file_id=abd3283f76d1
# INFO: partition finished in 16.07456895s, attributes: file_id=abd3283f76d1
# 2024-09-06 00:10:16,184 MainProcess INFO     partition finished in 16.053511487s, attributes: file_id=d3f25cd30105
# INFO: partition finished in 16.053511487s, attributes: file_id=d3f25cd30105
# 2024-09-06 00:10:17,702 MainProcess INFO     partition finished in 17.265161315s, attributes: file_id=c398325dcf56
# INFO: partition finished in 17.265161315s, attributes: file_id=c398325dcf56
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# 2024-09-06 00:10:19,181 MainProcess INFO     partition finished in 20.436733251s, attributes: file_id=e994c7cc1bc7
# INFO: partition finished in 20.436733251s, attributes: file_id=e994c7cc1bc7
# 2024-09-06 00:10:19,423 MainProcess INFO     partition finished in 18.23309102s, attributes: file_id=70728684bd95
# INFO: partition finished in 18.23309102s, attributes: file_id=70728684bd95
# 2024-09-06 00:10:19,610 MainProcess INFO     partition finished in 18.102079858s, attributes: file_id=2b66aba8df56
# INFO: partition finished in 18.102079858s, attributes: file_id=2b66aba8df56
# 2024-09-06 00:10:19,741 MainProcess INFO     partition finished in 17.31497949s, attributes: file_id=caea060664cc
# INFO: partition finished in 17.31497949s, attributes: file_id=caea060664cc
# 2024-09-06 00:10:20,078 MainProcess INFO     partition finished in 19.282848724s, attributes: file_id=f7b34d86c902
# INFO: partition finished in 19.282848724s, attributes: file_id=f7b34d86c902
# 2024-09-06 00:10:20,166 MainProcess INFO     partition finished in 17.420715782s, attributes: file_id=ff5318340c6e
# INFO: partition finished in 17.420715782s, attributes: file_id=ff5318340c6e
# 2024-09-06 00:10:20,348 MainProcess INFO     partition finished in 18.557730784s, attributes: file_id=9a39d2e29dcc
# INFO: partition finished in 18.557730784s, attributes: file_id=9a39d2e29dcc
# 2024-09-06 00:10:20,481 MainProcess INFO     partition finished in 18.35645399s, attributes: file_id=4e1ff8c3cfa6
# INFO: partition finished in 18.35645399s, attributes: file_id=4e1ff8c3cfa6
# 2024-09-06 00:10:20,568 MainProcess INFO     partition finished in 17.539793499s, attributes: file_id=c8861f9318ac
# INFO: partition finished in 17.539793499s, attributes: file_id=c8861f9318ac
# 2024-09-06 00:10:20,649 MainProcess INFO     partition finished in 17.126220814s, attributes: file_id=7ae5ed524fa3
# INFO: partition finished in 17.126220814s, attributes: file_id=7ae5ed524fa3
# 2024-09-06 00:10:20,865 MainProcess INFO     partition finished in 17.027324445s, attributes: file_id=a0fb12601f92
# INFO: partition finished in 17.027324445s, attributes: file_id=a0fb12601f92
# 2024-09-06 00:10:21,067 MainProcess INFO     partition finished in 16.893723381s, attributes: file_id=d4b5721fc6ac
# INFO: partition finished in 16.893723381s, attributes: file_id=d4b5721fc6ac
# 2024-09-06 00:10:21,249 MainProcess INFO     partition finished in 16.312316236s, attributes: file_id=c3a5f10725a8
# INFO: partition finished in 16.312316236s, attributes: file_id=c3a5f10725a8
# 2024-09-06 00:10:21,439 MainProcess INFO     partition finished in 16.106829932s, attributes: file_id=d01d0022be96
# INFO: partition finished in 16.106829932s, attributes: file_id=d01d0022be96
# 2024-09-06 00:10:21,630 MainProcess INFO     partition finished in 15.487989096s, attributes: file_id=b3d89bdb67ff
# INFO: partition finished in 15.487989096s, attributes: file_id=b3d89bdb67ff
# 2024-09-06 00:10:21,804 MainProcess INFO     partition finished in 15.92499737s, attributes: file_id=672104dd6749
# INFO: partition finished in 15.92499737s, attributes: file_id=672104dd6749
# 2024-09-06 00:10:22,029 MainProcess INFO     partition finished in 17.457909278s, attributes: file_id=d7d2922d94ba
# INFO: partition finished in 17.457909278s, attributes: file_id=d7d2922d94ba
# 2024-09-06 00:10:22,183 MainProcess INFO     partition finished in 15.100822816s, attributes: file_id=db2f21630cfc
# INFO: partition finished in 15.100822816s, attributes: file_id=db2f21630cfc
# 2024-09-06 00:10:22,371 MainProcess INFO     partition finished in 15.684325427s, attributes: file_id=f4ba9aae9cf9
# INFO: partition finished in 15.684325427s, attributes: file_id=f4ba9aae9cf9
# 2024-09-06 00:10:22,604 MainProcess INFO     partition finished in 16.182334542s, attributes: file_id=498c50401742
# INFO: partition finished in 16.182334542s, attributes: file_id=498c50401742
# 2024-09-06 00:10:22,806 MainProcess INFO     partition finished in 15.436921445s, attributes: file_id=f719093841a5
# INFO: partition finished in 15.436921445s, attributes: file_id=f719093841a5
# 2024-09-06 00:10:22,983 MainProcess INFO     partition finished in 15.173162872s, attributes: file_id=6bddf10193f2
# INFO: partition finished in 15.173162872s, attributes: file_id=6bddf10193f2
# 2024-09-06 00:10:23,162 MainProcess INFO     partition finished in 15.018153121s, attributes: file_id=ac75a8c380fe
# INFO: partition finished in 15.018153121s, attributes: file_id=ac75a8c380fe
# 2024-09-06 00:10:23,361 MainProcess INFO     partition finished in 14.237147616s, attributes: file_id=b62949260afa
# INFO: partition finished in 14.237147616s, attributes: file_id=b62949260afa
# 2024-09-06 00:10:23,588 MainProcess INFO     partition finished in 14.193251213s, attributes: file_id=d607933d117f
# INFO: partition finished in 14.193251213s, attributes: file_id=d607933d117f
# 2024-09-06 00:10:23,883 MainProcess INFO     partition finished in 15.048845446s, attributes: file_id=f97a843986db
# INFO: partition finished in 15.048845446s, attributes: file_id=f97a843986db
# 2024-09-06 00:10:24,207 MainProcess INFO     partition finished in 15.756740745s, attributes: file_id=6f763f4cca09
# INFO: partition finished in 15.756740745s, attributes: file_id=6f763f4cca09
# 2024-09-06 00:10:24,408 MainProcess INFO     partition finished in 14.651439818s, attributes: file_id=deb43f567179
# INFO: partition finished in 14.651439818s, attributes: file_id=deb43f567179
# 2024-09-06 00:10:24,603 MainProcess INFO     partition finished in 14.591137589s, attributes: file_id=7528aadeea11
# INFO: partition finished in 14.591137589s, attributes: file_id=7528aadeea11
# 2024-09-06 00:10:24,816 MainProcess INFO     partition finished in 14.533269234s, attributes: file_id=bdba1adc010f
# INFO: partition finished in 14.533269234s, attributes: file_id=bdba1adc010f
# 2024-09-06 00:10:25,012 MainProcess INFO     partition finished in 14.111212587s, attributes: file_id=13765ca921e7
# INFO: partition finished in 14.111212587s, attributes: file_id=13765ca921e7
# 2024-09-06 00:10:25,218 MainProcess INFO     partition finished in 14.614396801s, attributes: file_id=b38f5c0127d9
# INFO: partition finished in 14.614396801s, attributes: file_id=b38f5c0127d9
# 2024-09-06 00:10:25,416 MainProcess INFO     partition finished in 13.804181321s, attributes: file_id=c61a1e69b092
# INFO: partition finished in 13.804181321s, attributes: file_id=c61a1e69b092
# 2024-09-06 00:10:25,593 MainProcess INFO     partition finished in 13.196103241s, attributes: file_id=345d018cbbe5
# INFO: partition finished in 13.196103241s, attributes: file_id=345d018cbbe5
# 2024-09-06 00:10:25,805 MainProcess INFO     partition finished in 14.571991499s, attributes: file_id=ed6e53262aa7
# INFO: partition finished in 14.571991499s, attributes: file_id=ed6e53262aa7
# 2024-09-06 00:10:26,071 MainProcess INFO     partition finished in 13.996977727s, attributes: file_id=0d0f018e3413
# INFO: partition finished in 13.996977727s, attributes: file_id=0d0f018e3413
# 2024-09-06 00:10:26,224 MainProcess INFO     partition finished in 13.478797853s, attributes: file_id=c8772b42e222
# INFO: partition finished in 13.478797853s, attributes: file_id=c8772b42e222
# 2024-09-06 00:10:26,408 MainProcess INFO     partition finished in 13.381683638s, attributes: file_id=cbf0e997e940
# INFO: partition finished in 13.381683638s, attributes: file_id=cbf0e997e940
# 2024-09-06 00:10:26,540 MainProcess INFO     partition finished in 13.22436074s, attributes: file_id=0049b10a4583
# INFO: partition finished in 13.22436074s, attributes: file_id=0049b10a4583
# 2024-09-06 00:10:26,755 MainProcess INFO     partition finished in 13.111713672s, attributes: file_id=82b1d0b5fd74
# INFO: partition finished in 13.111713672s, attributes: file_id=82b1d0b5fd74
# 2024-09-06 00:10:26,765 MainProcess INFO     partition step finished in 28.028456973s
# INFO: partition step finished in 28.028456973s
# 2024-09-06 00:10:26,768 MainProcess INFO     Calling ChunkStep with 45 docs
# INFO: Calling ChunkStep with 45 docs
# 2024-09-06 00:10:26,772 MainProcess INFO     processing content across processes
# INFO: processing content across processes
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Overriding of current TracerProvider is not allowed
# Overriding of current TracerProvider is not allowed
# 2024-09-06 00:10:29,836 ForkPoolWorker-3 INFO     chunk finished in 2.965422136s, attributes: file_id=f7b34d86c902
# 2024-09-06 00:10:29,855 ForkPoolWorker-3 INFO     chunk finished in 2.991165893s, attributes: file_id=f7b34d86c902
# 2024-09-06 00:10:30,179 ForkPoolWorker-2 INFO     chunk finished in 3.327041152s, attributes: file_id=e994c7cc1bc7
# 2024-09-06 00:10:30,184 ForkPoolWorker-2 INFO     chunk finished in 3.336712522s, attributes: file_id=e994c7cc1bc7
# 2024-09-06 00:10:31,455 ForkPoolWorker-3 INFO     chunk finished in 1.584060404s, attributes: file_id=70728684bd95
# 2024-09-06 00:10:31,459 ForkPoolWorker-3 INFO     chunk finished in 1.589801112s, attributes: file_id=70728684bd95
# 2024-09-06 00:10:32,142 ForkPoolWorker-2 INFO     chunk finished in 1.935916569s, attributes: file_id=7b745a57b69d
# 2024-09-06 00:10:32,157 ForkPoolWorker-2 INFO     chunk finished in 1.953064138s, attributes: file_id=7b745a57b69d
# 2024-09-06 00:10:33,498 ForkPoolWorker-3 INFO     chunk finished in 2.028993229s, attributes: file_id=2b66aba8df56
# 2024-09-06 00:10:33,513 ForkPoolWorker-3 INFO     chunk finished in 2.044217448s, attributes: file_id=2b66aba8df56
# 2024-09-06 00:10:33,934 ForkPoolWorker-2 INFO     chunk finished in 1.770245652s, attributes: file_id=e9ed27e3b8d8
# 2024-09-06 00:10:33,945 ForkPoolWorker-2 INFO     chunk finished in 1.783355069s, attributes: file_id=e9ed27e3b8d8
# 2024-09-06 00:10:35,487 ForkPoolWorker-3 INFO     chunk finished in 1.965815562s, attributes: file_id=9a39d2e29dcc
# 2024-09-06 00:10:35,501 ForkPoolWorker-3 INFO     chunk finished in 1.980630996s, attributes: file_id=9a39d2e29dcc
# 2024-09-06 00:10:36,742 ForkPoolWorker-2 INFO     chunk finished in 2.78596476s, attributes: file_id=abd3283f76d1
# 2024-09-06 00:10:36,748 ForkPoolWorker-2 INFO     chunk finished in 2.792890757s, attributes: file_id=abd3283f76d1
# 2024-09-06 00:10:38,028 ForkPoolWorker-3 INFO     chunk finished in 2.522683645s, attributes: file_id=4e1ff8c3cfa6
# 2024-09-06 00:10:38,042 ForkPoolWorker-3 INFO     chunk finished in 2.537413958s, attributes: file_id=4e1ff8c3cfa6
# 2024-09-06 00:10:39,183 ForkPoolWorker-2 INFO     chunk finished in 2.370762588s, attributes: file_id=d3f25cd30105
# 2024-09-06 00:10:39,189 ForkPoolWorker-2 INFO     chunk finished in 2.377807573s, attributes: file_id=d3f25cd30105
# 2024-09-06 00:10:39,214 ForkPoolWorker-3 INFO     chunk finished in 1.164017332s, attributes: file_id=caea060664cc
# 2024-09-06 00:10:39,216 ForkPoolWorker-3 INFO     chunk finished in 1.166409237s, attributes: file_id=caea060664cc
# 2024-09-06 00:10:39,802 ForkPoolWorker-3 INFO     chunk finished in 0.568641705s, attributes: file_id=ff5318340c6e
# 2024-09-06 00:10:39,809 ForkPoolWorker-3 INFO     chunk finished in 0.575961765s, attributes: file_id=ff5318340c6e
# 2024-09-06 00:10:40,334 ForkPoolWorker-3 INFO     chunk finished in 0.518114613s, attributes: file_id=c8861f9318ac
# 2024-09-06 00:10:40,344 ForkPoolWorker-3 INFO     chunk finished in 0.528115227s, attributes: file_id=c8861f9318ac
# 2024-09-06 00:10:40,398 ForkPoolWorker-2 INFO     chunk finished in 1.19673372s, attributes: file_id=c398325dcf56
# 2024-09-06 00:10:40,406 ForkPoolWorker-2 INFO     chunk finished in 1.204476302s, attributes: file_id=c398325dcf56
# 2024-09-06 00:10:40,852 ForkPoolWorker-3 INFO     chunk finished in 0.500546837s, attributes: file_id=7ae5ed524fa3
# 2024-09-06 00:10:40,860 ForkPoolWorker-3 INFO     chunk finished in 0.509543192s, attributes: file_id=7ae5ed524fa3
# 2024-09-06 00:10:41,355 ForkPoolWorker-3 INFO     chunk finished in 0.484228835s, attributes: file_id=a0fb12601f92
# 2024-09-06 00:10:41,364 ForkPoolWorker-3 INFO     chunk finished in 0.494231713s, attributes: file_id=a0fb12601f92
# 2024-09-06 00:10:41,665 ForkPoolWorker-2 INFO     chunk finished in 1.24690896s, attributes: file_id=c3a5f10725a8
# 2024-09-06 00:10:41,674 ForkPoolWorker-2 INFO     chunk finished in 1.256270474s, attributes: file_id=c3a5f10725a8
# 2024-09-06 00:10:42,614 ForkPoolWorker-3 INFO     chunk finished in 1.246745632s, attributes: file_id=d4b5721fc6ac
# 2024-09-06 00:10:42,621 ForkPoolWorker-3 INFO     chunk finished in 1.254927195s, attributes: file_id=d4b5721fc6ac
# 2024-09-06 00:10:42,966 ForkPoolWorker-2 INFO     chunk finished in 1.282876607s, attributes: file_id=d01d0022be96
# 2024-09-06 00:10:42,974 ForkPoolWorker-2 INFO     chunk finished in 1.291310644s, attributes: file_id=d01d0022be96
# 2024-09-06 00:10:44,011 ForkPoolWorker-2 INFO     chunk finished in 1.028805865s, attributes: file_id=672104dd6749
# 2024-09-06 00:10:44,020 ForkPoolWorker-2 INFO     chunk finished in 1.038014132s, attributes: file_id=672104dd6749
# 2024-09-06 00:10:44,024 ForkPoolWorker-3 INFO     chunk finished in 1.391081026s, attributes: file_id=d7d2922d94ba
# 2024-09-06 00:10:44,029 ForkPoolWorker-3 INFO     chunk finished in 1.397113974s, attributes: file_id=d7d2922d94ba
# 2024-09-06 00:10:45,036 ForkPoolWorker-3 INFO     chunk finished in 0.993499567s, attributes: file_id=db2f21630cfc
# 2024-09-06 00:10:45,043 ForkPoolWorker-3 INFO     chunk finished in 1.001691739s, attributes: file_id=db2f21630cfc
# 2024-09-06 00:10:45,286 ForkPoolWorker-2 INFO     chunk finished in 1.25906646s, attributes: file_id=b3d89bdb67ff
# 2024-09-06 00:10:45,295 ForkPoolWorker-2 INFO     chunk finished in 1.26902596s, attributes: file_id=b3d89bdb67ff
# 2024-09-06 00:10:46,277 ForkPoolWorker-3 INFO     chunk finished in 1.223874867s, attributes: file_id=f719093841a5
# 2024-09-06 00:10:46,286 ForkPoolWorker-3 INFO     chunk finished in 1.233817318s, attributes: file_id=f719093841a5
# 2024-09-06 00:10:46,883 ForkPoolWorker-2 INFO     chunk finished in 1.57723032s, attributes: file_id=498c50401742
# 2024-09-06 00:10:46,885 ForkPoolWorker-2 INFO     chunk finished in 1.579639736s, attributes: file_id=498c50401742
# 2024-09-06 00:10:47,385 ForkPoolWorker-3 INFO     chunk finished in 1.090777214s, attributes: file_id=6bddf10193f2
# 2024-09-06 00:10:47,395 ForkPoolWorker-3 INFO     chunk finished in 1.100653293s, attributes: file_id=6bddf10193f2
# 2024-09-06 00:10:48,256 ForkPoolWorker-2 INFO     chunk finished in 1.362814728s, attributes: file_id=f4ba9aae9cf9
# 2024-09-06 00:10:48,258 ForkPoolWorker-2 INFO     chunk finished in 1.365300557s, attributes: file_id=f4ba9aae9cf9
# 2024-09-06 00:10:48,730 ForkPoolWorker-3 INFO     chunk finished in 1.327715981s, attributes: file_id=ac75a8c380fe
# 2024-09-06 00:10:48,738 ForkPoolWorker-3 INFO     chunk finished in 1.336132911s, attributes: file_id=ac75a8c380fe
# 2024-09-06 00:10:49,874 ForkPoolWorker-2 INFO     chunk finished in 1.600512795s, attributes: file_id=b62949260afa
# 2024-09-06 00:10:49,884 ForkPoolWorker-2 INFO     chunk finished in 1.611084467s, attributes: file_id=b62949260afa
# 2024-09-06 00:10:51,329 ForkPoolWorker-2 INFO     chunk finished in 1.431306467s, attributes: file_id=d607933d117f
# 2024-09-06 00:10:51,349 ForkPoolWorker-2 INFO     chunk finished in 1.451199045s, attributes: file_id=d607933d117f
# 2024-09-06 00:10:51,725 ForkPoolWorker-3 INFO     chunk finished in 2.984722709s, attributes: file_id=6f763f4cca09
# 2024-09-06 00:10:51,737 ForkPoolWorker-3 INFO     chunk finished in 2.996509289s, attributes: file_id=6f763f4cca09
# 2024-09-06 00:10:53,614 ForkPoolWorker-2 INFO     chunk finished in 2.261794446s, attributes: file_id=deb43f567179
# 2024-09-06 00:10:53,619 ForkPoolWorker-2 INFO     chunk finished in 2.267658311s, attributes: file_id=deb43f567179
# 2024-09-06 00:10:55,225 ForkPoolWorker-3 INFO     chunk finished in 3.481830124s, attributes: file_id=f97a843986db
# 2024-09-06 00:10:55,235 ForkPoolWorker-3 INFO     chunk finished in 3.492194505s, attributes: file_id=f97a843986db
# 2024-09-06 00:10:56,316 ForkPoolWorker-2 INFO     chunk finished in 2.689932488s, attributes: file_id=7528aadeea11
# 2024-09-06 00:10:56,320 ForkPoolWorker-2 INFO     chunk finished in 2.694042504s, attributes: file_id=7528aadeea11
# 2024-09-06 00:10:57,328 ForkPoolWorker-3 INFO     chunk finished in 2.069795851s, attributes: file_id=13765ca921e7
# 2024-09-06 00:10:57,350 ForkPoolWorker-3 INFO     chunk finished in 2.093060643s, attributes: file_id=13765ca921e7
# 2024-09-06 00:10:58,912 ForkPoolWorker-2 INFO     chunk finished in 2.574525389s, attributes: file_id=bdba1adc010f
# 2024-09-06 00:10:58,933 ForkPoolWorker-2 INFO     chunk finished in 2.596105951s, attributes: file_id=bdba1adc010f
# 2024-09-06 00:11:00,146 ForkPoolWorker-3 INFO     chunk finished in 2.793222824s, attributes: file_id=ed6e53262aa7
# 2024-09-06 00:11:00,157 ForkPoolWorker-3 INFO     chunk finished in 2.804979354s, attributes: file_id=ed6e53262aa7
# 2024-09-06 00:11:02,394 ForkPoolWorker-3 INFO     chunk finished in 2.226454276s, attributes: file_id=c61a1e69b092
# 2024-09-06 00:11:02,408 ForkPoolWorker-3 INFO     chunk finished in 2.241226753s, attributes: file_id=c61a1e69b092
# 2024-09-06 00:11:02,406 ForkPoolWorker-2 INFO     chunk finished in 3.455103701s, attributes: file_id=b38f5c0127d9
# 2024-09-06 00:11:02,415 ForkPoolWorker-2 INFO     chunk finished in 3.464783324s, attributes: file_id=b38f5c0127d9
# 2024-09-06 00:11:04,805 ForkPoolWorker-2 INFO     chunk finished in 2.348913286s, attributes: file_id=cbf0e997e940
# 2024-09-06 00:11:04,817 ForkPoolWorker-2 INFO     chunk finished in 2.361290996s, attributes: file_id=cbf0e997e940
# 2024-09-06 00:11:06,477 ForkPoolWorker-2 INFO     chunk finished in 1.647999222s, attributes: file_id=0049b10a4583
# 2024-09-06 00:11:06,487 ForkPoolWorker-2 INFO     chunk finished in 1.657753021s, attributes: file_id=0049b10a4583
# 2024-09-06 00:11:06,888 ForkPoolWorker-3 INFO     chunk finished in 4.468836441s, attributes: file_id=0d0f018e3413
# 2024-09-06 00:11:06,898 ForkPoolWorker-3 INFO     chunk finished in 4.478513284s, attributes: file_id=0d0f018e3413
# 2024-09-06 00:11:08,193 ForkPoolWorker-2 INFO     chunk finished in 1.69590442s, attributes: file_id=82b1d0b5fd74
# 2024-09-06 00:11:08,202 ForkPoolWorker-2 INFO     chunk finished in 1.706001459s, attributes: file_id=82b1d0b5fd74
# 2024-09-06 00:11:08,220 ForkPoolWorker-3 INFO     chunk finished in 1.31147315s, attributes: file_id=345d018cbbe5
# 2024-09-06 00:11:08,221 ForkPoolWorker-3 INFO     chunk finished in 1.3135297s, attributes: file_id=345d018cbbe5
# 2024-09-06 00:11:08,777 ForkPoolWorker-3 INFO     chunk finished in 0.551507098s, attributes: file_id=c8772b42e222
# 2024-09-06 00:11:08,779 ForkPoolWorker-3 INFO     chunk finished in 0.553789199s, attributes: file_id=c8772b42e222
# 2024-09-06 00:11:08,861 MainProcess INFO     chunk step finished in 42.093083641s
# INFO: chunk step finished in 42.093083641s
# 2024-09-06 00:11:08,869 MainProcess INFO     Calling EmbedStep with 45 docs
# INFO: Calling EmbedStep with 45 docs
# 2024-09-06 00:11:08,875 MainProcess INFO     processing content across processes
# INFO: processing content across processes
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Overriding of current TracerProvider is not allowed
# Overriding of current TracerProvider is not allowed
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# 2024-09-06 00:11:25,360 ForkPoolWorker-5 INFO     embed finished in 16.379051708s, attributes: file_id=f7b34d86c902
# 2024-09-06 00:11:25,371 ForkPoolWorker-5 INFO     embed finished in 16.394443823s, attributes: file_id=f7b34d86c902
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# 2024-09-06 00:11:26,423 ForkPoolWorker-4 INFO     embed finished in 17.451024352s, attributes: file_id=e994c7cc1bc7
# 2024-09-06 00:11:26,425 ForkPoolWorker-4 INFO     embed finished in 17.459836527s, attributes: file_id=e994c7cc1bc7
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# 2024-09-06 00:11:31,288 ForkPoolWorker-5 INFO     embed finished in 5.907507812s, attributes: file_id=70728684bd95
# 2024-09-06 00:11:31,303 ForkPoolWorker-5 INFO     embed finished in 5.923678563s, attributes: file_id=70728684bd95
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# 2024-09-06 00:11:36,472 ForkPoolWorker-4 INFO     embed finished in 10.040978441s, attributes: file_id=7b745a57b69d
# 2024-09-06 00:11:36,484 ForkPoolWorker-4 INFO     embed finished in 10.055035558s, attributes: file_id=7b745a57b69d
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# 2024-09-06 00:11:43,794 ForkPoolWorker-5 INFO     embed finished in 12.477753717s, attributes: file_id=2b66aba8df56
# 2024-09-06 00:11:43,805 ForkPoolWorker-5 INFO     embed finished in 12.489491478s, attributes: file_id=2b66aba8df56
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# 2024-09-06 00:11:46,749 ForkPoolWorker-4 INFO     embed finished in 10.25387267s, attributes: file_id=e9ed27e3b8d8
# 2024-09-06 00:11:46,758 ForkPoolWorker-4 INFO     embed finished in 10.268351343s, attributes: file_id=e9ed27e3b8d8
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# 2024-09-06 00:11:51,476 ForkPoolWorker-5 INFO     embed finished in 7.667786801s, attributes: file_id=9a39d2e29dcc
# 2024-09-06 00:11:51,478 ForkPoolWorker-5 INFO     embed finished in 7.670604352s, attributes: file_id=9a39d2e29dcc
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# 2024-09-06 00:11:57,080 ForkPoolWorker-4 INFO     embed finished in 10.314102339s, attributes: file_id=abd3283f76d1
# 2024-09-06 00:11:57,097 ForkPoolWorker-4 INFO     embed finished in 10.331464113s, attributes: file_id=abd3283f76d1
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# 2024-09-06 00:12:02,349 ForkPoolWorker-5 INFO     embed finished in 10.859498276s, attributes: file_id=4e1ff8c3cfa6
# 2024-09-06 00:12:02,356 ForkPoolWorker-5 INFO     embed finished in 10.867630195s, attributes: file_id=4e1ff8c3cfa6
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# 2024-09-06 00:12:07,088 ForkPoolWorker-4 INFO     embed finished in 9.984458512s, attributes: file_id=d3f25cd30105
# 2024-09-06 00:12:07,096 ForkPoolWorker-4 INFO     embed finished in 9.993138957s, attributes: file_id=d3f25cd30105
# 2024-09-06 00:12:07,451 ForkPoolWorker-5 INFO     embed finished in 5.083546601s, attributes: file_id=caea060664cc
# 2024-09-06 00:12:07,453 ForkPoolWorker-5 INFO     embed finished in 5.085787933s, attributes: file_id=caea060664cc
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# 2024-09-06 00:12:11,977 ForkPoolWorker-5 INFO     embed finished in 4.511535316s, attributes: file_id=ff5318340c6e
# 2024-09-06 00:12:11,986 ForkPoolWorker-5 INFO     embed finished in 4.521596046s, attributes: file_id=ff5318340c6e
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# 2024-09-06 00:12:16,467 ForkPoolWorker-4 INFO     embed finished in 9.362970282s, attributes: file_id=c398325dcf56
# 2024-09-06 00:12:16,476 ForkPoolWorker-4 INFO     embed finished in 9.372758033s, attributes: file_id=c398325dcf56
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# 2024-09-06 00:12:19,112 ForkPoolWorker-5 INFO     embed finished in 7.117964919s, attributes: file_id=c8861f9318ac
# 2024-09-06 00:12:19,126 ForkPoolWorker-5 INFO     embed finished in 7.132623797s, attributes: file_id=c8861f9318ac
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# 2024-09-06 00:12:24,475 ForkPoolWorker-5 INFO     embed finished in 5.337212883s, attributes: file_id=7ae5ed524fa3
# 2024-09-06 00:12:24,485 ForkPoolWorker-5 INFO     embed finished in 5.348271538s, attributes: file_id=7ae5ed524fa3
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# ...
# 2024-09-06 00:15:08,530 MainProcess INFO     Calling UploadStep with 45 docs
# INFO: Calling UploadStep with 45 docs
# 2024-09-06 00:15:08,534 MainProcess INFO     processing content across processes
# INFO: processing content across processes
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Overriding of current TracerProvider is not allowed
# Overriding of current TracerProvider is not allowed
# 2024-09-06 00:15:08,696 ForkPoolWorker-9 INFO     writing 100 objects to destination collection ninatest
# 2024-09-06 00:15:08,697 ForkPoolWorker-8 INFO     writing 116 objects to destination collection ninatest
# 2024-09-06 00:15:11,685 ForkPoolWorker-9 INFO     upload finished in 3.047901152s, attributes: file_id=f7b34d86c902
# 2024-09-06 00:15:11,687 ForkPoolWorker-9 INFO     upload finished in 3.053426162s, attributes: file_id=f7b34d86c902
# 2024-09-06 00:15:11,710 ForkPoolWorker-9 INFO     writing 44 objects to destination collection ninatest
# 2024-09-06 00:15:11,723 ForkPoolWorker-8 INFO     upload finished in 3.102681276s, attributes: file_id=e994c7cc1bc7
# 2024-09-06 00:15:11,725 ForkPoolWorker-8 INFO     upload finished in 3.10860585s, attributes: file_id=e994c7cc1bc7
# 2024-09-06 00:15:11,752 ForkPoolWorker-8 INFO     writing 70 objects to destination collection ninatest
# 2024-09-06 00:15:14,063 ForkPoolWorker-9 INFO     upload finished in 2.368890813s, attributes: file_id=70728684bd95
# 2024-09-06 00:15:14,067 ForkPoolWorker-9 INFO     upload finished in 2.376794424s, attributes: file_id=70728684bd95
# 2024-09-06 00:15:14,099 ForkPoolWorker-9 INFO     writing 78 objects to destination collection ninatest
# 2024-09-06 00:15:14,203 ForkPoolWorker-8 INFO     upload finished in 2.469848774s, attributes: file_id=7b745a57b69d
# 2024-09-06 00:15:14,205 ForkPoolWorker-8 INFO     upload finished in 2.474915296s, attributes: file_id=7b745a57b69d
# 2024-09-06 00:15:14,232 ForkPoolWorker-8 INFO     writing 74 objects to destination collection ninatest
# 2024-09-06 00:15:16,597 ForkPoolWorker-9 INFO     upload finished in 2.523353382s, attributes: file_id=2b66aba8df56
# 2024-09-06 00:15:16,607 ForkPoolWorker-9 INFO     upload finished in 2.534178182s, attributes: file_id=2b66aba8df56
# 2024-09-06 00:15:16,658 ForkPoolWorker-9 INFO     writing 75 objects to destination collection ninatest
# 2024-09-06 00:15:16,779 ForkPoolWorker-8 INFO     upload finished in 2.56908804s, attributes: file_id=e9ed27e3b8d8
# 2024-09-06 00:15:16,783 ForkPoolWorker-8 INFO     upload finished in 2.573717402s, attributes: file_id=e9ed27e3b8d8
# 2024-09-06 00:15:16,831 ForkPoolWorker-8 INFO     writing 81 objects to destination collection ninatest
# 2024-09-06 00:15:19,204 ForkPoolWorker-9 INFO     upload finished in 2.585483291s, attributes: file_id=9a39d2e29dcc
# 2024-09-06 00:15:19,209 ForkPoolWorker-9 INFO     upload finished in 2.591474784s, attributes: file_id=9a39d2e29dcc
# 2024-09-06 00:15:19,247 ForkPoolWorker-9 INFO     writing 53 objects to destination collection ninatest
# 2024-09-06 00:15:19,400 ForkPoolWorker-8 INFO     upload finished in 2.610101582s, attributes: file_id=abd3283f76d1
# 2024-09-06 00:15:19,404 ForkPoolWorker-8 INFO     upload finished in 2.61767482s, attributes: file_id=abd3283f76d1
# 2024-09-06 00:15:19,446 ForkPoolWorker-8 INFO     writing 67 objects to destination collection ninatest
# 2024-09-06 00:15:21,606 ForkPoolWorker-9 INFO     upload finished in 2.390173803s, attributes: file_id=4e1ff8c3cfa6
# 2024-09-06 00:15:21,608 ForkPoolWorker-9 INFO     upload finished in 2.392835589s, attributes: file_id=4e1ff8c3cfa6
# 2024-09-06 00:15:21,629 ForkPoolWorker-9 INFO     writing 38 objects to destination collection ninatest
# 2024-09-06 00:15:21,875 ForkPoolWorker-8 INFO     upload finished in 2.466430153s, attributes: file_id=d3f25cd30105
# 2024-09-06 00:15:21,877 ForkPoolWorker-8 INFO     upload finished in 2.469371869s, attributes: file_id=d3f25cd30105
# 2024-09-06 00:15:21,901 ForkPoolWorker-8 INFO     writing 65 objects to destination collection ninatest
# 2024-09-06 00:15:23,912 ForkPoolWorker-9 INFO     upload finished in 2.296151087s, attributes: file_id=caea060664cc
# 2024-09-06 00:15:23,914 ForkPoolWorker-9 INFO     upload finished in 2.298501286s, attributes: file_id=caea060664cc
# 2024-09-06 00:15:23,942 ForkPoolWorker-9 INFO     writing 37 objects to destination collection ninatest
# 2024-09-06 00:15:24,346 ForkPoolWorker-8 INFO     upload finished in 2.466463252s, attributes: file_id=c398325dcf56
# 2024-09-06 00:15:24,348 ForkPoolWorker-8 INFO     upload finished in 2.468939145s, attributes: file_id=c398325dcf56
# 2024-09-06 00:15:24,381 ForkPoolWorker-8 INFO     writing 76 objects to destination collection ninatest
# 2024-09-06 00:15:26,230 ForkPoolWorker-9 INFO     upload finished in 2.303193946s, attributes: file_id=ff5318340c6e
# 2024-09-06 00:15:26,232 ForkPoolWorker-9 INFO     upload finished in 2.305540872s, attributes: file_id=ff5318340c6e
# 2024-09-06 00:15:26,250 ForkPoolWorker-9 INFO     writing 34 objects to destination collection ninatest
# 2024-09-06 00:15:26,841 ForkPoolWorker-8 INFO     upload finished in 2.486298937s, attributes: file_id=c3a5f10725a8
# 2024-09-06 00:15:26,842 ForkPoolWorker-8 INFO     upload finished in 2.488615943s, attributes: file_id=c3a5f10725a8
# 2024-09-06 00:15:26,871 ForkPoolWorker-8 INFO     writing 75 objects to destination collection ninatest
# 2024-09-06 00:15:28,551 ForkPoolWorker-9 INFO     upload finished in 2.314696278s, attributes: file_id=c8861f9318ac
# 2024-09-06 00:15:28,553 ForkPoolWorker-9 INFO     upload finished in 2.318962464s, attributes: file_id=c8861f9318ac
# 2024-09-06 00:15:28,572 ForkPoolWorker-9 INFO     writing 32 objects to destination collection ninatest
# 2024-09-06 00:15:29,401 ForkPoolWorker-8 INFO     upload finished in 2.556081254s, attributes: file_id=d01d0022be96
# 2024-09-06 00:15:29,403 ForkPoolWorker-8 INFO     upload finished in 2.55819807s, attributes: file_id=d01d0022be96
# 2024-09-06 00:15:29,426 ForkPoolWorker-8 INFO     writing 53 objects to destination collection ninatest
# 2024-09-06 00:15:30,867 ForkPoolWorker-9 INFO     upload finished in 2.310805923s, attributes: file_id=7ae5ed524fa3
# 2024-09-06 00:15:30,871 ForkPoolWorker-9 INFO     upload finished in 2.314845418s, attributes: file_id=7ae5ed524fa3
# 2024-09-06 00:15:30,905 ForkPoolWorker-9 INFO     writing 30 objects to destination collection ninatest
# 2024-09-06 00:15:31,832 ForkPoolWorker-8 INFO     upload finished in 2.426260627s, attributes: file_id=672104dd6749
# 2024-09-06 00:15:31,836 ForkPoolWorker-8 INFO     upload finished in 2.430708555s, attributes: file_id=672104dd6749
# 2024-09-06 00:15:31,883 ForkPoolWorker-8 INFO     writing 66 objects to destination collection ninatest
# 2024-09-06 00:15:33,211 ForkPoolWorker-9 INFO     upload finished in 2.336316212s, attributes: file_id=a0fb12601f92
# 2024-09-06 00:15:33,215 ForkPoolWorker-9 INFO     upload finished in 2.341297224s, attributes: file_id=a0fb12601f92
# 2024-09-06 00:15:33,260 ForkPoolWorker-9 INFO     writing 67 objects to destination collection ninatest
# 2024-09-06 00:15:34,387 ForkPoolWorker-8 INFO     upload finished in 2.542302721s, attributes: file_id=b3d89bdb67ff
# 2024-09-06 00:15:34,391 ForkPoolWorker-8 INFO     upload finished in 2.547358586s, attributes: file_id=b3d89bdb67ff
# 2024-09-06 00:15:34,440 ForkPoolWorker-8 INFO     writing 94 objects to destination collection ninatest
# 2024-09-06 00:15:35,730 ForkPoolWorker-9 INFO     upload finished in 2.506313638s, attributes: file_id=d4b5721fc6ac
# 2024-09-06 00:15:35,736 ForkPoolWorker-9 INFO     upload finished in 2.513679068s, attributes: file_id=d4b5721fc6ac
# 2024-09-06 00:15:35,776 ForkPoolWorker-9 INFO     writing 86 objects to destination collection ninatest
# 2024-09-06 00:15:36,990 ForkPoolWorker-8 INFO     upload finished in 2.592776021s, attributes: file_id=498c50401742
# 2024-09-06 00:15:36,995 ForkPoolWorker-8 INFO     upload finished in 2.598750464s, attributes: file_id=498c50401742
# 2024-09-06 00:15:37,041 ForkPoolWorker-8 INFO     writing 66 objects to destination collection ninatest
# 2024-09-06 00:15:38,380 ForkPoolWorker-9 INFO     upload finished in 2.638003013s, attributes: file_id=d7d2922d94ba
# 2024-09-06 00:15:38,384 ForkPoolWorker-9 INFO     upload finished in 2.641876473s, attributes: file_id=d7d2922d94ba
# 2024-09-06 00:15:38,439 ForkPoolWorker-9 INFO     writing 53 objects to destination collection ninatest
# 2024-09-06 00:15:39,521 ForkPoolWorker-8 INFO     upload finished in 2.519169353s, attributes: file_id=f4ba9aae9cf9
# 2024-09-06 00:15:39,527 ForkPoolWorker-8 INFO     upload finished in 2.52512169s, attributes: file_id=f4ba9aae9cf9
# 2024-09-06 00:15:39,599 ForkPoolWorker-8 INFO     writing 82 objects to destination collection ninatest
# 2024-09-06 00:15:40,803 ForkPoolWorker-9 INFO     upload finished in 2.387780786s, attributes: file_id=db2f21630cfc
# 2024-09-06 00:15:40,805 ForkPoolWorker-9 INFO     upload finished in 2.390757847s, attributes: file_id=db2f21630cfc
# 2024-09-06 00:15:40,835 ForkPoolWorker-9 INFO     writing 80 objects to destination collection ninatest
# 2024-09-06 00:15:42,510 ForkPoolWorker-8 INFO     upload finished in 2.961781384s, attributes: file_id=b62949260afa
# 2024-09-06 00:15:42,512 ForkPoolWorker-8 INFO     upload finished in 2.964155526s, attributes: file_id=b62949260afa
# 2024-09-06 00:15:42,536 ForkPoolWorker-8 INFO     writing 55 objects to destination collection ninatest
# 2024-09-06 00:15:43,306 ForkPoolWorker-9 INFO     upload finished in 2.495929041s, attributes: file_id=f719093841a5
# 2024-09-06 00:15:43,308 ForkPoolWorker-9 INFO     upload finished in 2.498363102s, attributes: file_id=f719093841a5
# 2024-09-06 00:15:43,334 ForkPoolWorker-9 INFO     writing 58 objects to destination collection ninatest
# 2024-09-06 00:15:44,964 ForkPoolWorker-8 INFO     upload finished in 2.445813422s, attributes: file_id=d607933d117f
# 2024-09-06 00:15:44,971 ForkPoolWorker-8 INFO     upload finished in 2.453841911s, attributes: file_id=d607933d117f
# 2024-09-06 00:15:45,021 ForkPoolWorker-8 INFO     writing 78 objects to destination collection ninatest
# 2024-09-06 00:15:45,765 ForkPoolWorker-9 INFO     upload finished in 2.453730351s, attributes: file_id=6bddf10193f2
# 2024-09-06 00:15:45,770 ForkPoolWorker-9 INFO     upload finished in 2.459480284s, attributes: file_id=6bddf10193f2
# 2024-09-06 00:15:45,821 ForkPoolWorker-9 INFO     writing 72 objects to destination collection ninatest
# 2024-09-06 00:15:47,565 ForkPoolWorker-8 INFO     upload finished in 2.589988965s, attributes: file_id=deb43f567179
# 2024-09-06 00:15:47,569 ForkPoolWorker-8 INFO     upload finished in 2.594488206s, attributes: file_id=deb43f567179
# 2024-09-06 00:15:47,608 ForkPoolWorker-8 INFO     writing 62 objects to destination collection ninatest
# 2024-09-06 00:15:48,330 ForkPoolWorker-9 INFO     upload finished in 2.553485626s, attributes: file_id=ac75a8c380fe
# 2024-09-06 00:15:48,332 ForkPoolWorker-9 INFO     upload finished in 2.556158102s, attributes: file_id=ac75a8c380fe
# 2024-09-06 00:15:48,397 ForkPoolWorker-9 INFO     writing 125 objects to destination collection ninatest
# 2024-09-06 00:15:50,058 ForkPoolWorker-8 INFO     upload finished in 2.482279865s, attributes: file_id=7528aadeea11
# 2024-09-06 00:15:50,060 ForkPoolWorker-8 INFO     upload finished in 2.484890708s, attributes: file_id=7528aadeea11
# 2024-09-06 00:15:50,105 ForkPoolWorker-8 INFO     writing 80 objects to destination collection ninatest
# 2024-09-06 00:15:51,081 ForkPoolWorker-9 INFO     upload finished in 2.746259791s, attributes: file_id=6f763f4cca09
# 2024-09-06 00:15:51,083 ForkPoolWorker-9 INFO     upload finished in 2.748598758s, attributes: file_id=6f763f4cca09
# 2024-09-06 00:15:51,123 ForkPoolWorker-9 INFO     writing 100 objects to destination collection ninatest
# 2024-09-06 00:15:52,570 ForkPoolWorker-8 INFO     upload finished in 2.507390423s, attributes: file_id=bdba1adc010f
# 2024-09-06 00:15:52,572 ForkPoolWorker-8 INFO     upload finished in 2.509771823s, attributes: file_id=bdba1adc010f
# 2024-09-06 00:15:52,602 ForkPoolWorker-8 INFO     writing 70 objects to destination collection ninatest
# 2024-09-06 00:15:53,657 ForkPoolWorker-9 INFO     upload finished in 2.570734264s, attributes: file_id=f97a843986db
# 2024-09-06 00:15:53,659 ForkPoolWorker-9 INFO     upload finished in 2.57320478s, attributes: file_id=f97a843986db
# 2024-09-06 00:15:53,689 ForkPoolWorker-9 INFO     writing 63 objects to destination collection ninatest
# 2024-09-06 00:15:55,038 ForkPoolWorker-8 INFO     upload finished in 2.462169893s, attributes: file_id=b38f5c0127d9
# 2024-09-06 00:15:55,040 ForkPoolWorker-8 INFO     upload finished in 2.464619126s, attributes: file_id=b38f5c0127d9
# 2024-09-06 00:15:55,073 ForkPoolWorker-8 INFO     writing 73 objects to destination collection ninatest
# 2024-09-06 00:15:56,115 ForkPoolWorker-9 INFO     upload finished in 2.444860172s, attributes: file_id=13765ca921e7
# 2024-09-06 00:15:56,117 ForkPoolWorker-9 INFO     upload finished in 2.447549069s, attributes: file_id=13765ca921e7
# 2024-09-06 00:15:56,164 ForkPoolWorker-9 INFO     writing 77 objects to destination collection ninatest
# 2024-09-06 00:15:57,527 ForkPoolWorker-8 INFO     upload finished in 2.476300297s, attributes: file_id=cbf0e997e940
# 2024-09-06 00:15:57,528 ForkPoolWorker-8 INFO     upload finished in 2.478621991s, attributes: file_id=cbf0e997e940
# 2024-09-06 00:15:57,553 ForkPoolWorker-8 INFO     writing 52 objects to destination collection ninatest
# 2024-09-06 00:15:58,610 ForkPoolWorker-9 INFO     upload finished in 2.490178315s, attributes: file_id=ed6e53262aa7
# 2024-09-06 00:15:58,617 ForkPoolWorker-9 INFO     upload finished in 2.497052445s, attributes: file_id=ed6e53262aa7
# 2024-09-06 00:15:58,646 ForkPoolWorker-9 INFO     writing 78 objects to destination collection ninatest
# 2024-09-06 00:15:59,940 ForkPoolWorker-8 INFO     upload finished in 2.40526774s, attributes: file_id=0049b10a4583
# 2024-09-06 00:15:59,944 ForkPoolWorker-8 INFO     upload finished in 2.410211788s, attributes: file_id=0049b10a4583
# 2024-09-06 00:15:59,994 ForkPoolWorker-8 INFO     writing 74 objects to destination collection ninatest
# 2024-09-06 00:16:01,189 ForkPoolWorker-9 INFO     upload finished in 2.567180641s, attributes: file_id=c61a1e69b092
# 2024-09-06 00:16:01,192 ForkPoolWorker-9 INFO     upload finished in 2.571697808s, attributes: file_id=c61a1e69b092
# 2024-09-06 00:16:01,252 ForkPoolWorker-9 INFO     writing 101 objects to destination collection ninatest
# 2024-09-06 00:16:02,544 ForkPoolWorker-8 INFO     upload finished in 2.592591519s, attributes: file_id=82b1d0b5fd74
# 2024-09-06 00:16:02,546 ForkPoolWorker-8 INFO     upload finished in 2.595665903s, attributes: file_id=82b1d0b5fd74
# 2024-09-06 00:16:03,847 ForkPoolWorker-9 INFO     upload finished in 2.648565755s, attributes: file_id=0d0f018e3413
# 2024-09-06 00:16:03,849 ForkPoolWorker-9 INFO     upload finished in 2.650883715s, attributes: file_id=0d0f018e3413
# 2024-09-06 00:16:03,875 ForkPoolWorker-9 INFO     writing 59 objects to destination collection ninatest
# 2024-09-06 00:16:06,269 ForkPoolWorker-9 INFO     upload finished in 2.417599145s, attributes: file_id=345d018cbbe5
# 2024-09-06 00:16:06,271 ForkPoolWorker-9 INFO     upload finished in 2.419887975s, attributes: file_id=345d018cbbe5
# 2024-09-06 00:16:06,296 ForkPoolWorker-9 INFO     writing 55 objects to destination collection ninatest
# 2024-09-06 00:16:08,659 ForkPoolWorker-9 INFO     upload finished in 2.384182508s, attributes: file_id=c8772b42e222
# 2024-09-06 00:16:08,661 ForkPoolWorker-9 INFO     upload finished in 2.386663107s, attributes: file_id=c8772b42e222
# 2024-09-06 00:16:08,730 MainProcess INFO     upload step finished in 60.198632321s
# INFO: upload step finished in 60.198632321s
# 2024-09-06 00:16:08,738 MainProcess INFO     ingest process finished in 374.993472358s
# INFO: ingest process finished in 374.993472358s
